# %% [markdown]
# # **To-Do List**

# %%
# To-Do List

tasks = []

def add_task():
    task = input("Enter Task: ")

    tasks.append({
        "task": task,
        "completed": False
    })

    print("Task Added.")


def view_tasks():

    if not tasks:
        print("No Tasks Available.")
        return

    print("\nYour Tasks\n")

    for i, task in enumerate(tasks, start=1):

        status = "Done" if task["completed"] else "Pending"

        print(f"{i}. {task['task']} [{status}]")


def complete_task():

    view_tasks()

    if not tasks:
        return

    number = int(input("Task Number: "))

    if 1 <= number <= len(tasks):
        tasks[number - 1]["completed"] = True
        print("Task Completed.")
    else:
        print("Invalid Task Number.")


def delete_task():

    view_tasks()

    if not tasks:
        return

    number = int(input("Task Number: "))

    if 1 <= number <= len(tasks):
        tasks.pop(number - 1)
        print("Task Deleted.")
    else:
        print("Invalid Task Number.")


while True:

    print("\nTo-Do List")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Complete Task")
    print("4. Delete Task")
    print("5. Exit")

    choice = input("Choice: ")

    if choice == "1":
        add_task()

    elif choice == "2":
        view_tasks()

    elif choice == "3":
        complete_task()

    elif choice == "4":
        delete_task()

    elif choice == "5":
        print("Goodbye!")
        break

    else:
        print("Invalid Choice")
# Out:
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 1
# Enter Task: Wake up in the Morning.
# Task Added.
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 1
# Enter Task: Brush your Teeth.
# Task Added.
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 1
# Enter Task: Take a bath
# Task Added.
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 1
# Enter Task: Go to College
# Task Added.
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 1
# Enter Task: Do your Homework
# Task Added.
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 1
# Enter Task: Get full Diet
# Task Added.
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 1
# Enter Task: Do exercise
# Task Added.
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 1
# Enter Task: Have dinner
# Task Added.
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 1
# Enter Task: Sleep Early
# Task Added.
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 2
#
# Your Tasks
#
# 1. Wake up in the Morning. [Pending]
# 2. Brush your Teeth. [Pending]
# 3. Take a bath [Pending]
# 4. Go to College [Pending]
# 5. Do your Homework [Pending]
# 6. Get full Diet [Pending]
# 7. Do exercise [Pending]
# 8. Have dinner [Pending]
# 9. Sleep Early [Pending]
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 3
#
# Your Tasks
#
# 1. Wake up in the Morning. [Pending]
# 2. Brush your Teeth. [Pending]
# 3. Take a bath [Pending]
# 4. Go to College [Pending]
# 5. Do your Homework [Pending]
# 6. Get full Diet [Pending]
# 7. Do exercise [Pending]
# 8. Have dinner [Pending]
# 9. Sleep Early [Pending]
# Task Number: 4
# Task Completed.
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 3
#
# Your Tasks
#
# 1. Wake up in the Morning. [Pending]
# 2. Brush your Teeth. [Pending]
# 3. Take a bath [Pending]
# 4. Go to College [Done]
# 5. Do your Homework [Pending]
# 6. Get full Diet [Pending]
# 7. Do exercise [Pending]
# 8. Have dinner [Pending]
# 9. Sleep Early [Pending]
# Task Number: 1
# Task Completed.
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 4
#
# Your Tasks
#
# 1. Wake up in the Morning. [Done]
# 2. Brush your Teeth. [Pending]
# 3. Take a bath [Pending]
# 4. Go to College [Done]
# 5. Do your Homework [Pending]
# 6. Get full Diet [Pending]
# 7. Do exercise [Pending]
# 8. Have dinner [Pending]
# 9. Sleep Early [Pending]
# Task Number: 6
# Task Deleted.
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 2
#
# Your Tasks
#
# 1. Wake up in the Morning. [Done]
# 2. Brush your Teeth. [Pending]
# 3. Take a bath [Pending]
# 4. Go to College [Done]
# 5. Do your Homework [Pending]
# 6. Do exercise [Pending]
# 7. Have dinner [Pending]
# 8. Sleep Early [Pending]
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 5
# Goodbye!
