# %% [markdown]
# # **ATM System**

# %%
# ATM System using Exception Handling

balance = 10000.0


def check_balance():
    print(f"\nAvailable Balance : ₹{balance:.2f}")


def deposit():
    global balance

    try:
        amount = float(input("Enter deposit amount: ₹"))

        if amount <= 0:
            raise ValueError("Deposit amount must be greater than zero.")

    except ValueError as error:
        print(f"Error: {error}")

    else:
        balance += amount
        print(f"₹{amount:.2f} deposited successfully.")
        print(f"Updated Balance : ₹{balance:.2f}")

    finally:
        print("Deposit transaction completed.\n")


def withdraw():
    global balance

    try:
        amount = float(input("Enter withdrawal amount: ₹"))

        if amount <= 0:
            raise ValueError("Withdrawal amount must be greater than zero.")

        if amount > balance:
            raise Exception("Insufficient balance.")

    except ValueError as error:
        print(f"Error: {error}")

    except Exception as error:
        print(f"Error: {error}")

    else:
        balance -= amount
        print(f"₹{amount:.2f} withdrawn successfully.")
        print(f"Remaining Balance : ₹{balance:.2f}")

    finally:
        print("Withdrawal transaction completed.\n")


while True:

    print("=" * 40)
    print("ATM MENU")
    print("=" * 40)
    print("1. Check Balance")
    print("2. Deposit")
    print("3. Withdraw")
    print("4. Exit")

    try:
        choice = int(input("Enter your choice: "))

        if choice == 1:
            check_balance()

        elif choice == 2:
            deposit()

        elif choice == 3:
            withdraw()

        elif choice == 4:
            print("\nThank you for using our ATM.")
            break

        else:
            print("Invalid menu choice.")

    except ValueError:
        print("Please enter a valid number.")

    finally:
        print("-" * 40)
# Out:
# ========================================
# ATM MENU
# ========================================
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 1
#
# Available Balance : ₹10000.00
# ----------------------------------------
# ========================================
# ATM MENU
# ========================================
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 2
# Enter deposit amount: ₹0
# Error: Deposit amount must be greater than zero.
# Deposit transaction completed.
#
# ----------------------------------------
# ========================================
# ATM MENU
# ========================================
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 2
# Enter deposit amount: ₹90000
# ₹90000.00 deposited successfully.
# Updated Balance : ₹100000.00
# Deposit transaction completed.
#
# ----------------------------------------
# ========================================
# ATM MENU
# ========================================
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 3
# Enter withdrawal amount: ₹0
# Error: Withdrawal amount must be greater than zero.
# Withdrawal transaction completed.
#
# ----------------------------------------
# ========================================
# ATM MENU
# ========================================
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 3
# Enter withdrawal amount: ₹1000000
# Error: Insufficient balance.
# Withdrawal transaction completed.
#
# ----------------------------------------
# ========================================
# ATM MENU
# ========================================
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 100
# Invalid menu choice.
# ----------------------------------------
# ========================================
# ATM MENU
# ========================================
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 3
# Enter withdrawal amount: ₹1000
# ₹1000.00 withdrawn successfully.
# Remaining Balance : ₹99000.00
# Withdrawal transaction completed.
#
# ----------------------------------------
# ========================================
# ATM MENU
# ========================================
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 1
#
# Available Balance : ₹99000.00
# ----------------------------------------
# ========================================
# ATM MENU
# ========================================
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice: 4
#
# Thank you for using our ATM.
# ----------------------------------------
